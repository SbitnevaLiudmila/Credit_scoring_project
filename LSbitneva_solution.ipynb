# %% [markdown]
# ## <center>Курсовой проект<a class="anchor" id="course_project"></a><center>

# %% [markdown]
# ### Постановка задачи<a class="anchor" id="course_project_task"></a>

# %% [markdown]
# **Задача**
#
# Требуется, на основании имеющихся данных о клиентах банка, построить модель, используя обучающий датасет, для прогнозирования невыполнения долговых обязательств по текущему кредиту. Выполнить прогноз для примеров из тестового датасета.
#
# **Наименование файлов с данными**
#
# course_project_train.csv - обучающий датасет<br>
# course_project_test.csv - тестовый датасет
#
# **Целевая переменная**
#
# Credit Default - факт невыполнения кредитных обязательств
#
# **Метрика качества**
#
# F1-score (sklearn.metrics.f1_score)
#
# **Требования к решению**
#
# *Целевая метрика*
# * F1 > 0.5
# * Метрика оценивается по качеству прогноза для главного класса (1 - просрочка по кредиту)
#
# *Решение должно содержать*
# 1. Тетрадка Jupyter Notebook с кодом Вашего решения, названная по образцу {ФИО}\_solution.ipynb, пример SShirkin\_solution.ipynb
# 2. Файл CSV с прогнозами целевой переменной для тестового датасета, названный по образцу {ФИО}\_predictions.csv, пример SShirkin\_predictions.csv
#
# *Рекомендации для файла с кодом (ipynb)*
# 1. Файл должен содержать заголовки и комментарии (markdown)
# 2. Повторяющиеся операции лучше оформлять в виде функций
# 3. Не делать вывод большого количества строк таблиц (5-10 достаточно)
# 4. По возможности добавлять графики, описывающие данные (около 3-5)
# 5. Добавлять только лучшую модель, то есть не включать в код все варианты решения проекта
# 6. Скрипт проекта должен отрабатывать от начала и до конца (от загрузки данных до выгрузки предсказаний)
# 7. Весь проект должен быть в одном скрипте (файл ipynb).
# 8. Допускается применение библиотек Python и моделей машинного обучения,
# которые были в данном курсе.
#
# **Сроки сдачи**
#
# Cдать проект нужно в течение 5 дней после окончания последнего вебинара.
# Оценки работ, сданных до дедлайна, будут представлены в виде рейтинга, ранжированного по заданной метрике качества.
# Проекты, сданные после дедлайна или сданные повторно, не попадают в рейтинг, но можно будет узнать результат.

# %% [markdown]
# ### Примерное описание этапов выполнения курсового проекта<a class="anchor" id="course_project_steps"></a>

# %% [markdown]
# **Построение модели классификации**
# 1. Обзор обучающего датасета
# 2. Обработка выбросов
# 3. Обработка пропусков
# 4. Анализ данных
# 5. Отбор признаков
# 6. Балансировка классов
# 7. Подбор моделей, получение бейзлана
# 8. Выбор наилучшей модели, настройка гиперпараметров
# 9. Проверка качества, борьба с переобучением
# 10. Интерпретация результатов
#
# **Прогнозирование на тестовом датасете**
# 1. Выполнить для тестового датасета те же этапы обработки и постронияния признаков
# 2. Спрогнозировать целевую переменную, используя модель, построенную на обучающем датасете
# 3. Прогнозы должны быть для всех примеров из тестового датасета (для всех строк)
# 4. Соблюдать исходный порядок примеров из тестового датасета

# %% [markdown]
# ### Обзор данных<a class="anchor" id="course_project_review"></a>

# %% [markdown]
# **Описание датасета**
#
# * **Home Ownership** - домовладение
# * **Annual Income** - годовой доход
# * **Years in current job** - количество лет на текущем месте работы
# * **Tax Liens** - налоговые обременения
# * **Number of Open Accounts** - количество открытых счетов
# * **Years of Credit History** - количество лет кредитной истории
# * **Maximum Open Credit** - наибольший открытый кредит
# * **Number of Credit Problems** - количество проблем с кредитом
# * **Months since last delinquent** - количество месяцев с последней просрочки платежа
# * **Bankruptcies** - банкротства
# * **Purpose** - цель кредита
# * **Term** - срок кредита
# * **Current Loan Amount** - текущая сумма кредита
# * **Current Credit Balance** - текущий кредитный баланс
# * **Monthly Debt** - ежемесячный долг
# * **Credit Default** - факт невыполнения кредитных обязательств (0 - погашен вовремя, 1 - просрочка)

# %%
#!pip install xgboost (conda install -c mndrake xgboost)
#!pip install lightgbm
#!pip install catboost

# %%
import pandas as pd
import numpy as np
import pickle
import random

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score, learning_curve
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb, lightgbm as lgbm, catboost as catb

import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
matplotlib.rcParams.update({'font.size': 14})

# %% [markdown]
# **Пути к директориям и файлам**

# %%
TRAIN_DATASET_PATH = 'course_project_train.csv'
TEST_DATASET_PATH = 'course_project_test.csv'

# %% [markdown]
# **Загрузка данных**

# %%
df_train = pd.read_csv(TRAIN_DATASET_PATH)
df_train.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  NaN        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                           NaN           1.0
# 1                        0.0                           NaN           0.0
# 2                        0.0                           NaN           0.0
# 3                        1.0                           NaN           1.0
# 4                        1.0                           NaN           0.0
#
#               Purpose        Term  Current Loan Amount  \
# 0  debt consolidation  Short Term           99999999.0
# 1  debt consolidation   Long Term             264968.0
# 2  debt consolidation  Short Term           99999999.0
# 3  debt consolidation  Short Term             121396.0
# 4  debt consolidation  Short Term             125840.0
#
#    Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                 47386.0        7914.0         749.0               0
# 1                394972.0       18373.0         737.0               1
# 2                308389.0       13651.0         742.0               0
# 3                 95855.0       11338.0         694.0               0
# 4                 93309.0        7180.0         719.0               0

# %%
df_train.tail(n=3)
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 7497           Rent      1878910.0              6 years        0.0
# 7498  Home Mortgage            NaN                  NaN        0.0
# 7499           Rent            NaN              4 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 7497                     12.0                     32.1            1778920.0
# 7498                     21.0                     26.5            1141250.0
# 7499                      8.0                      9.4             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 7497                        0.0                           NaN           0.0
# 7498                        0.0                           NaN           0.0
# 7499                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 7497           buy a car  Short Term           99999999.0
# 7498  debt consolidation  Short Term             615274.0
# 7499  debt consolidation  Short Term              26928.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 7497                477812.0       12479.0         748.0               0
# 7498                476064.0       37118.0           NaN               0
# 7499                288192.0        9061.0           NaN               0

# %%
df_train.shape
# Out:
# (7500, 17)

# %%
df_train.iloc[0]
# Out:
# Home Ownership                            Own Home
# Annual Income                               482087
# Years in current job                           NaN
# Tax Liens                                        0
# Number of Open Accounts                         11
# Years of Credit History                       26.3
# Maximum Open Credit                         685960
# Number of Credit Problems                        1
# Months since last delinquent                   NaN
# Bankruptcies                                     1
# Purpose                         debt consolidation
# Term                                    Short Term
# Current Loan Amount                          1e+08
# Current Credit Balance                       47386
# Monthly Debt                                  7914
# Credit Score                                   749
# Credit Default                                   0
# Name: 0, dtype: object

# %%
df_train['Credit Default'].value_counts()
# Out:
# 0    5387
# 1    2113
# Name: Credit Default, dtype: int64

# %%
df_test = pd.read_csv(TEST_DATASET_PATH)
df_test.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0           Rent            NaN              4 years        0.0
# 1           Rent       231838.0               1 year        0.0
# 2  Home Mortgage      1152540.0              3 years        0.0
# 3  Home Mortgage      1220313.0            10+ years        0.0
# 4  Home Mortgage      2340952.0              6 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                      9.0                     12.5             220968.0
# 1                      6.0                     32.7              55946.0
# 2                     10.0                     13.7             204600.0
# 3                     16.0                     17.0             456302.0
# 4                     11.0                     23.6            1207272.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        0.0                          70.0           0.0
# 1                        0.0                           8.0           0.0
# 2                        0.0                           NaN           0.0
# 3                        0.0                          70.0           0.0
# 4                        0.0                           NaN           0.0
#
#                 Purpose        Term  Current Loan Amount  \
# 0    debt consolidation  Short Term             162470.0
# 1  educational expenses  Short Term              78298.0
# 2    debt consolidation  Short Term             200178.0
# 3    debt consolidation  Short Term             217382.0
# 4    debt consolidation   Long Term             777634.0
#
#    Current Credit Balance  Monthly Debt  Credit Score
# 0                105906.0        6813.0           NaN
# 1                 46037.0        2318.0         699.0
# 2                146490.0       18729.0        7260.0
# 3                213199.0       27559.0         739.0
# 4                425391.0       42605.0         706.0

# %%
df_test.tail(n=3)
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 2497  Home Mortgage      1171806.0              2 years        0.0
# 2498           Rent       723520.0            10+ years        0.0
# 2499           Rent      1694439.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 2497                     48.0                     12.8            1706430.0
# 2498                     14.0                     28.8             945780.0
# 2499                     12.0                     18.4            1199748.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 2497                        0.0                           NaN           0.0
# 2498                        0.0                           NaN           0.0
# 2499                        1.0                          72.0           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 2497  debt consolidation  Short Term             430496.0
# 2498  debt consolidation  Short Term             257774.0
# 2499  debt consolidation   Long Term             763004.0
#
#       Current Credit Balance  Monthly Debt  Credit Score
# 2497                676438.0       36912.0         695.0
# 2498                391248.0       13506.0         744.0
# 2499                559531.0       23440.0        6820.0

# %%
df_test.shape
# Out:
# (2500, 16)

# %%
# проверка размерности
df_train.shape[1]-1 == df_test.shape[1]
# Out:
# True

# %%
# объединение трейн и тест
data = pd.concat([df_train, df_test], axis=0)
data = data.reset_index(drop=True)
data.shape
# Out:
# (10000, 17)

# %%
x_train = data[data["Credit Default"].notnull()]
x_test = data[data["Credit Default"].isnull()]

# %%
x_test.shape
# Out:
# (2500, 17)

# %%
data.head(10)
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  NaN        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
# 5           Rent            NaN              7 years        0.0
# 6  Home Mortgage      1511108.0            10+ years        0.0
# 7           Rent      1040060.0            10+ years        0.0
# 8  Home Mortgage            NaN              5 years        0.0
# 9  Home Mortgage            NaN               1 year        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
# 5                     12.0                     14.6             366784.0
# 6                      9.0                     20.3             388124.0
# 7                     13.0                     12.0             330374.0
# 8                     17.0                     15.7                  0.0
# 9                     10.0                     24.6             511302.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                           NaN           1.0
# 1                        0.0                           NaN           0.0
# 2                        0.0                           NaN           0.0
# 3                        1.0                           NaN           1.0
# 4                        1.0                           NaN           0.0
# 5                        0.0                           NaN           0.0
# 6                        0.0                          73.0           0.0
# 7                        0.0                          18.0           0.0
# 8                        1.0                           NaN           1.0
# 9                        0.0                           6.0           0.0
#
#               Purpose        Term  Current Loan Amount  \
# 0  debt consolidation  Short Term           99999999.0
# 1  debt consolidation   Long Term             264968.0
# 2  debt consolidation  Short Term           99999999.0
# 3  debt consolidation  Short Term             121396.0
# 4  debt consolidation  Short Term             125840.0
# 5               other   Long Term             337304.0
# 6   home improvements  Short Term           99999999.0
# 7               other  Short Term             250888.0
# 8   home improvements  Short Term             129734.0
# 9  debt consolidation   Long Term             572880.0
#
#    Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                 47386.0        7914.0         749.0             0.0
# 1                394972.0       18373.0         737.0             1.0
# 2                308389.0       13651.0         742.0             0.0
# 3                 95855.0       11338.0         694.0             0.0
# 4                 93309.0        7180.0         719.0             0.0
# 5                165680.0       18692.0           NaN             1.0
# 6                 51623.0        2317.0         745.0             0.0
# 7                 89015.0       19761.0         705.0             1.0
# 8                    19.0          17.0           NaN             0.0
# 9                205333.0       17613.0           NaN             1.0

# %% [markdown]
# ### Приведение типов данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                10000 non-null  object
#  1   Annual Income                 7930 non-null   float64
#  2   Years in current job          9543 non-null   object
#  3   Tax Liens                     10000 non-null  float64
#  4   Number of Open Accounts       10000 non-null  float64
#  5   Years of Credit History       10000 non-null  float64
#  6   Maximum Open Credit           10000 non-null  float64
#  7   Number of Credit Problems     10000 non-null  float64
#  8   Months since last delinquent  4561 non-null   float64
#  9   Bankruptcies                  9983 non-null   float64
#  10  Purpose                       10000 non-null  object
#  11  Term                          10000 non-null  object
#  12  Current Loan Amount           10000 non-null  float64
#  13  Current Credit Balance        10000 non-null  float64
#  14  Monthly Debt                  10000 non-null  float64
#  15  Credit Score                  7930 non-null   float64
#  16  Credit Default                7500 non-null   float64
# dtypes: float64(13), object(4)
# memory usage: 1.3+ MB

# %%
for colname in ['Home Ownership', 'Years in current job', 'Purpose',  'Term']:
    data[colname] = data[colname].astype(str)

# %%
data.dtypes
# Out:
# Home Ownership                   object
# Annual Income                   float64
# Years in current job             object
# Tax Liens                       float64
# Number of Open Accounts         float64
# Years of Credit History         float64
# Maximum Open Credit             float64
# Number of Credit Problems       float64
# Months since last delinquent    float64
# Bankruptcies                    float64
# Purpose                          object
# Term                             object
# Current Loan Amount             float64
# Current Credit Balance          float64
# Monthly Debt                    float64
# Credit Score                    float64
# Credit Default                  float64
# dtype: object

# %% [markdown]
# ### Обзор данных

# %%
TARGET_NAME = 'Credit Default'
BASE_FEATURE_NAMES = data.columns.drop(TARGET_NAME).tolist()
NEW_FEATURE_NAMES = data.columns.drop([TARGET_NAME] + BASE_FEATURE_NAMES)

# %%
# обзор целевой переменной
x_train['Credit Default'].value_counts()
# Out:
# 0.0    5387
# 1.0    2113
# Name: Credit Default, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.countplot(x='Credit Default', data=data)

plt.title('Target variable distribution')
plt.show()

# %%
corr_with_target = data[BASE_FEATURE_NAMES + [TARGET_NAME]].corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %% [markdown]
# **Оценка признака "Credit Score" в разрезе целевой переменной**

# %%
plt.figure(figsize=(10, 8))

sns.countplot(x="Credit Score", hue=TARGET_NAME, data=data)
plt.title('Credit Score grouped by target variable')
plt.legend(title='Target', loc='upper right')

plt.show()

# %% [markdown]
# **Матрица корреляций**

# %%
plt.figure(figsize = (25,20))

sns.set(font_scale=1.4)
sns.heatmap(data[BASE_FEATURE_NAMES].corr().round(3), annot=True, linewidths=.5, cmap='GnBu')

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# **Обзор категориальных признаков**

# %%
for cat_colname in data.select_dtypes(include='object').columns:
    print(str(cat_colname) + '\n\n' + str(data[cat_colname].value_counts()) + '\n' + '*' * 100 + '\n')
# Out:
# Home Ownership
#
# Home Mortgage    4862
# Rent             4224
# Own Home          895
# Have Mortgage      19
# Name: Home Ownership, dtype: int64
# ****************************************************************************************************
#
# Years in current job
#
# 10+ years    3142
# 2 years       917
# 3 years       848
# < 1 year      770
# 5 years       685
# 1 year        657
# 4 years       621
# 6 years       563
# 7 years       536
# nan           457
# 8 years       446
# 9 years       358
# Name: Years in current job, dtype: int64
# ****************************************************************************************************
#
# Purpose
#
# debt consolidation      7917
# other                    905
# home improvements        552
# business loan            159
# buy a car                130
# medical bills             98
# buy house                 53
# take a trip               51
# major purchase            49
# small business            31
# wedding                   17
# educational expenses      13
# moving                    12
# vacation                  11
# renewable energy           2
# Name: Purpose, dtype: int64
# ****************************************************************************************************
#
# Term
#
# Short Term    7417
# Long Term     2583
# Name: Term, dtype: int64
# ****************************************************************************************************

# %% [markdown]
# ### Обработка пропусков и выбросов по каждому признаку

# %%
data.describe()
# Out:
#        Annual Income     Tax Liens  Number of Open Accounts  \
# count   7.930000e+03  10000.000000              10000.00000
# mean    1.366525e+06      0.031400                 11.14430
# std     8.638276e+05      0.304341                  4.89476
# min     1.065330e+05      0.000000                  1.00000
# 25%     8.459892e+05      0.000000                  8.00000
# 50%     1.168814e+06      0.000000                 10.00000
# 75%     1.638693e+06      0.000000                 14.00000
# max     1.497561e+07     15.000000                 48.00000
#
#        Years of Credit History  Maximum Open Credit  \
# count             10000.000000         1.000000e+04
# mean                 18.319580         8.865079e+05
# std                   7.095357         1.389982e+07
# min                   3.900000         0.000000e+00
# 25%                  13.500000         2.788115e+05
# 50%                  17.000000         4.781810e+05
# 75%                  22.000000         7.943595e+05
# max                  57.700000         1.304726e+09
#
#        Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# count                10000.00000                   4561.000000   9983.000000
# mean                     0.16800                     34.564569      0.114595
# std                      0.51459                     21.771990      0.349729
# min                      0.00000                      0.000000      0.000000
# 25%                      0.00000                     16.000000      0.000000
# 50%                      0.00000                     32.000000      0.000000
# 75%                      0.00000                     50.000000      0.000000
# max                     15.00000                    118.000000      5.000000
#
#        Current Loan Amount  Current Credit Balance   Monthly Debt  \
# count         1.000000e+04            1.000000e+04   10000.000000
# mean          1.194381e+07            2.914741e+05   18303.675600
# std           3.200878e+07            3.339979e+05   11831.647516
# min           1.124200e+04            0.000000e+00       0.000000
# 25%           1.805485e+05            1.132258e+05   10059.750000
# 50%           3.117180e+05            2.090190e+05   16200.000000
# 75%           5.210700e+05            3.619500e+05   23888.250000
# max           1.000000e+08            6.506797e+06  136679.000000
#
#        Credit Score  Credit Default
# count   7930.000000     7500.000000
# mean    1171.992182        0.281733
# std     1639.812951        0.449874
# min      585.000000        0.000000
# 25%      711.000000        0.000000
# 50%      731.000000        0.000000
# 75%      743.000000        1.000000
# max     7510.000000        1.000000

# %%
len(data) - data.count()
#data.isnull().sum()
# Out:
# Home Ownership                     0
# Annual Income                   2070
# Years in current job               0
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent    5439
# Bankruptcies                      17
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                    2070
# Credit Default                  2500
# dtype: int64

# %% [markdown]
# **Home Ownership**

# %%
data['Home Ownership'].value_counts()
# Out:
# Home Mortgage    4862
# Rent             4224
# Own Home          895
# Have Mortgage      19
# Name: Home Ownership, dtype: int64

# %% [markdown]
# **Annual Income**

# %%
data["Annual Income"].isnull().sum()
# Out:
# 2070

# %%
#проверим, есть ли с нулевым значением
data.loc[(data["Annual Income"] == 0)]
# Out:
# Empty DataFrame
# Columns: [Home Ownership, Annual Income, Years in current job, Tax Liens, Number of Open Accounts, Years of Credit History, Maximum Open Credit, Number of Credit Problems, Months since last delinquent, Bankruptcies, Purpose, Term, Current Loan Amount, Current Credit Balance, Monthly Debt, Credit Score, Credit Default]
# Index: []

# %%
data["Annual Income"].describe()
# Out:
# count    7.930000e+03
# mean     1.366525e+06
# std      8.638276e+05
# min      1.065330e+05
# 25%      8.459892e+05
# 50%      1.168814e+06
# 75%      1.638693e+06
# max      1.497561e+07
# Name: Annual Income, dtype: float64

# %%
# так как ежемесячный платеж сильно связан с годовым доходом, посчитаем примерно, во сколько раз, создадим новую переменную
data['ratio_ann_income/monthlydebt'] = data['Annual Income'] / data['Monthly Debt']

# %%
data["ratio_ann_income/monthlydebt"].describe()
# Out:
# count    7930.000000
# mean             inf
# std              NaN
# min        30.074509
# 25%        52.863297
# 50%        71.426678
# 75%       107.139192
# max              inf
# Name: ratio_ann_income/monthlydebt, dtype: float64

# %%
# заполняю пропуски так: ежемесячный платеж умножить на случайное отношенинии годового дохода к ежемесячному платежу
data.loc[data['Annual Income'].isnull(), "Annual Income"] = data['Monthly Debt'] * random.randrange(30,110,10)

# %%
#удаляю вспомогательное отношение
del data['ratio_ann_income/monthlydebt']

# %%
data["Annual Income"].isnull().sum()
# Out:
# 0

# %%
data["Annual Income"].describe()
# Out:
# count    1.000000e+04
# mean     1.388996e+06
# std      8.829591e+05
# min      0.000000e+00
# 25%      8.417955e+05
# 50%      1.206348e+06
# 75%      1.706780e+06
# max      1.497561e+07
# Name: Annual Income, dtype: float64

# %%
data.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  nan        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                           NaN           1.0
# 1                        0.0                           NaN           0.0
# 2                        0.0                           NaN           0.0
# 3                        1.0                           NaN           1.0
# 4                        1.0                           NaN           0.0
#
#               Purpose        Term  Current Loan Amount  \
# 0  debt consolidation  Short Term           99999999.0
# 1  debt consolidation   Long Term             264968.0
# 2  debt consolidation  Short Term           99999999.0
# 3  debt consolidation  Short Term             121396.0
# 4  debt consolidation  Short Term             125840.0
#
#    Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                 47386.0        7914.0         749.0             0.0
# 1                394972.0       18373.0         737.0             1.0
# 2                308389.0       13651.0         742.0             0.0
# 3                 95855.0       11338.0         694.0             0.0
# 4                 93309.0        7180.0         719.0             0.0

# %% [markdown]
# **Years in current job**

# %%
data['Years in current job'].value_counts()
# Out:
# 10+ years    3142
# 2 years       917
# 3 years       848
# < 1 year      770
# 5 years       685
# 1 year        657
# 4 years       621
# 6 years       563
# 7 years       536
# nan           457
# 8 years       446
# 9 years       358
# Name: Years in current job, dtype: int64

# %%
# есть выброс nan, заменим его на моду
data.replace({'Years in current job': {'nan':data['Years in current job'].mode()[0]}}, inplace=True)

# %%
data['Years in current job'].value_counts()
# Out:
# 10+ years    3599
# 2 years       917
# 3 years       848
# < 1 year      770
# 5 years       685
# 1 year        657
# 4 years       621
# 6 years       563
# 7 years       536
# 8 years       446
# 9 years       358
# Name: Years in current job, dtype: int64

# %%
# тестировала другие интервалы в этом признаке, не повлияло на модель
#data.replace({'Years in current job':{'1 year':'1_3 years', '2 years':'1_3 years', '3 years':'1_3 years'}}, inplace=True)
#data.replace({'Years in current job':{'4 years':'4_9 years', '5 years':'4_9 years', '6 years':'4_9 years', '7 years':'4_9 years', '8 years':'4_9 years', '9 years':'4_9 years'}}, inplace=True)

# %%
data['Years in current job'].value_counts()
# Out:
# 10+ years    3599
# 2 years       917
# 3 years       848
# < 1 year      770
# 5 years       685
# 1 year        657
# 4 years       621
# 6 years       563
# 7 years       536
# 8 years       446
# 9 years       358
# Name: Years in current job, dtype: int64

# %% [markdown]
# **Tax Liens**

# %%
data['Tax Liens'].value_counts()
# Out:
# 0.0     9811
# 1.0      128
# 2.0       35
# 3.0       11
# 4.0        7
# 5.0        3
# 6.0        3
# 15.0       1
# 7.0        1
# Name: Tax Liens, dtype: int64

# %%
data.loc[(data['Tax Liens'] > 3)]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 1129           Rent      1691019.0              5 years        4.0
# 1214           Rent      3061584.0              2 years        6.0
# 2716  Home Mortgage      2522611.0            10+ years        5.0
# 3028           Rent      1386720.0            10+ years        4.0
# 3435           Rent      1231561.0            10+ years        5.0
# 3814           Rent      1254513.0               1 year        4.0
# 4122  Home Mortgage      3297412.0             < 1 year        4.0
# 4774       Own Home      1268896.0            10+ years        4.0
# 5373       Own Home      1711881.0            10+ years        6.0
# 5969           Rent      2897310.0            10+ years        7.0
# 6907       Own Home      1935760.0              7 years        4.0
# 7955  Home Mortgage       715103.0            10+ years        5.0
# 8077           Rent      3380594.0              3 years        4.0
# 8318  Home Mortgage      1161090.0            10+ years        6.0
# 9782       Own Home      1410294.0            10+ years       15.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 1129                     11.0                     20.4             681934.0
# 1214                     14.0                     28.9             949564.0
# 2716                      7.0                     14.4             235994.0
# 3028                     11.0                     25.0             344102.0
# 3435                      9.0                     16.0             518892.0
# 3814                      5.0                     10.5             122804.0
# 4122                     13.0                     35.3             320474.0
# 4774                     15.0                     15.8            3278000.0
# 5373                     12.0                     15.4             551166.0
# 5969                      9.0                     20.0             434126.0
# 6907                     15.0                     12.1             421916.0
# 7955                     12.0                     12.0             440176.0
# 8077                      3.0                     18.6             125004.0
# 8318                     26.0                     15.4              64988.0
# 9782                      5.0                     20.1             478984.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 1129                        6.0                          71.0           2.0
# 1214                        6.0                          67.0           0.0
# 2716                        6.0                          56.0           1.0
# 3028                        5.0                          81.0           1.0
# 3435                        5.0                          71.0           0.0
# 3814                        5.0                          36.0           0.0
# 4122                        4.0                          37.0           0.0
# 4774                        5.0                          18.0           1.0
# 5373                        6.0                          26.0           0.0
# 5969                        7.0                          54.0           0.0
# 6907                        4.0                          49.0           0.0
# 7955                        5.0                           NaN           0.0
# 8077                        5.0                           NaN           1.0
# 8318                        7.0                          16.0           0.0
# 9782                       15.0                          42.0           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 1129      major purchase   Long Term             543906.0
# 1214  debt consolidation  Short Term           99999999.0
# 2716       business loan  Short Term             342650.0
# 3028  debt consolidation  Short Term             312444.0
# 3435               other   Long Term             345708.0
# 3814  debt consolidation  Short Term             193864.0
# 4122               other   Long Term             763620.0
# 4774  debt consolidation  Short Term             268356.0
# 5373  debt consolidation  Short Term             313654.0
# 5969       medical bills  Short Term             782782.0
# 6907  debt consolidation  Short Term             218460.0
# 7955  debt consolidation  Short Term             224686.0
# 8077  debt consolidation  Short Term             546700.0
# 8318  debt consolidation  Short Term             108108.0
# 9782  debt consolidation  Short Term             447392.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 1129                116014.0       38753.0         693.0             0.0
# 1214                352640.0       29595.0         740.0             0.0
# 2716                110257.0       14610.0         711.0             0.0
# 3028                230318.0       17334.0           NaN             1.0
# 3435                163571.0       17242.0         708.0             1.0
# 3814                 31920.0        1965.0         716.0             1.0
# 4122                100472.0       31875.0         647.0             0.0
# 4774                939892.0       14698.0         739.0             0.0
# 5373                295602.0       36092.0         741.0             0.0
# 5969                275576.0       37182.0         716.0             0.0
# 6907                201134.0       24197.0           NaN             1.0
# 7955                130017.0       12693.0         727.0             NaN
# 8077                  9500.0        1014.0         703.0             NaN
# 8318                 48773.0        8786.0         705.0             NaN
# 9782                301549.0       15513.0         746.0             NaN

# %%
# есть значения 5,6,7,15 - их очень мало, 15 встречается только в тест

# %% [markdown]
# **Number of Open Accounts**

# %%
data['Number of Open Accounts'].value_counts()
# Out:
# 9.0     973
# 11.0    903
# 10.0    895
# 8.0     861
# 7.0     789
# 12.0    766
# 6.0     687
# 13.0    643
# 14.0    579
# 5.0     431
# 15.0    410
# 16.0    346
# 17.0    298
# 4.0     275
# 18.0    195
# 19.0    185
# 20.0    130
# 3.0     124
# 21.0    107
# 23.0     76
# 22.0     75
# 24.0     59
# 25.0     38
# 2.0      35
# 27.0     24
# 26.0     17
# 28.0     17
# 30.0     17
# 29.0     11
# 33.0      8
# 31.0      7
# 32.0      6
# 34.0      3
# 37.0      2
# 41.0      1
# 48.0      1
# 38.0      1
# 1.0       1
# 36.0      1
# 42.0      1
# 35.0      1
# 43.0      1
# Name: Number of Open Accounts, dtype: int64

# %%
# считаю, что здесь все ок

# %% [markdown]
# **Years of Credit History**

# %%
data['Years of Credit History'].value_counts()
# Out:
# 16.0    131
# 15.0    126
# 16.5    126
# 17.0    116
# 14.0    115
#        ...
# 36.1      1
# 48.3      1
# 35.7      1
# 49.3      1
# 45.9      1
# Name: Years of Credit History, Length: 423, dtype: int64

# %%
data.loc[(data["Years of Credit History"] == 0)]
# Out:
# Empty DataFrame
# Columns: [Home Ownership, Annual Income, Years in current job, Tax Liens, Number of Open Accounts, Years of Credit History, Maximum Open Credit, Number of Credit Problems, Months since last delinquent, Bankruptcies, Purpose, Term, Current Loan Amount, Current Credit Balance, Monthly Debt, Credit Score, Credit Default]
# Index: []

# %%
data.loc[(data["Years of Credit History"] > 50 )]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 247   Home Mortgage      1893426.0            10+ years        0.0
# 476   Home Mortgage      1076768.0            10+ years        0.0
# 3091           Rent       582141.0            10+ years        0.0
# 3628       Own Home       376314.0            10+ years        0.0
# 4301  Home Mortgage      2262400.0            10+ years        0.0
# 4716           Rent      1323280.0            10+ years        0.0
# 5673  Home Mortgage       949810.0            10+ years        0.0
# 7251  Home Mortgage      1801280.0            10+ years        0.0
# 8493  Home Mortgage      2028400.0            10+ years        0.0
# 8768       Own Home      1742661.0              8 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 247                       7.0                     52.2             711524.0
# 476                      14.0                     57.7             432124.0
# 3091                      7.0                     50.9             487498.0
# 3628                      8.0                     51.3             139436.0
# 4301                     19.0                     51.9            1602524.0
# 4716                      5.0                     51.5             485672.0
# 5673                     15.0                     50.6            1180388.0
# 7251                      8.0                     51.0            1769900.0
# 8493                     19.0                     50.9             941226.0
# 8768                     19.0                     53.4            1417174.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 247                         0.0                           NaN           0.0
# 476                         0.0                          24.0           0.0
# 3091                        0.0                           NaN           0.0
# 3628                        1.0                           NaN           1.0
# 4301                        0.0                          17.0           0.0
# 4716                        0.0                          14.0           0.0
# 5673                        0.0                          71.0           0.0
# 7251                        0.0                          27.0           0.0
# 8493                        0.0                          48.0           0.0
# 8768                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 247   debt consolidation   Long Term             429880.0
# 476   debt consolidation   Long Term             558360.0
# 3091  debt consolidation  Short Term           99999999.0
# 3628  debt consolidation  Short Term              78980.0
# 4301   home improvements  Short Term             108152.0
# 4716  debt consolidation   Long Term             614614.0
# 5673  debt consolidation   Long Term             439912.0
# 7251  debt consolidation   Long Term             439252.0
# 8493  debt consolidation  Short Term             219252.0
# 8768  debt consolidation  Short Term             448404.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 247                 500802.0       41024.0         654.0             1.0
# 476                 186219.0       13818.0         667.0             1.0
# 3091                228190.0        7180.0         750.0             0.0
# 3628                 99712.0        9972.0         720.0             0.0
# 4301                384750.0       28280.0           NaN             0.0
# 4716                416518.0       16541.0           NaN             1.0
# 5673                486267.0       15514.0         727.0             0.0
# 7251               1369577.0       22516.0           NaN             1.0
# 8493                481232.0       25355.0           NaN             NaN
# 8768                652346.0       35870.0         701.0             NaN

# %%
# считаю, что здесь все хорошо

# %% [markdown]
# **Maximum Open Credit**

# %%
data['Maximum Open Credit'].value_counts()
# Out:
# 0.0         79
# 319110.0     5
# 294030.0     4
# 382954.0     4
# 334796.0     4
#             ..
# 360118.0     1
# 430980.0     1
# 472736.0     1
# 225060.0     1
# 413644.0     1
# Name: Maximum Open Credit, Length: 9096, dtype: int64

# %%
data['Maximum Open Credit'].sort_values().unique()
# Out:
# array([0.00000000e+00, 4.33400000e+03, 4.44400000e+03, ...,
#        2.65512874e+08, 3.80052288e+08, 1.30472617e+09])

# %%
data["Maximum Open Credit"].max()
# Out:
# 1304726170.0

# %%
data.loc[(data["Maximum Open Credit"] > 100000000 )]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 44    Have Mortgage      1334256.0            10+ years        0.0
# 617   Home Mortgage       439360.0              3 years        0.0
# 2617  Home Mortgage      3217802.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 44                       17.0                     15.4         3.800523e+08
# 617                      13.0                     27.5         1.304726e+09
# 2617                     12.0                     35.5         2.655129e+08
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 44                          1.0                          35.0           0.0
# 617                         0.0                           NaN           0.0
# 2617                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 44           take a trip  Short Term              33110.0
# 617   debt consolidation  Short Term             529892.0
# 2617               other  Short Term              50116.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 44                  656450.0       34357.0         729.0             0.0
# 617                1126814.0        5492.0           NaN             0.0
# 2617               1834450.0       20272.0         750.0             0.0

# %%
# думаю, эти три суммы ошибочные, удаление их показало улучшение модели

# %%
data.drop([44, 617, 2617], inplace=True)

# %%
data.loc[(data["Maximum Open Credit"] > 100000000 )]
# Out:
# Empty DataFrame
# Columns: [Home Ownership, Annual Income, Years in current job, Tax Liens, Number of Open Accounts, Years of Credit History, Maximum Open Credit, Number of Credit Problems, Months since last delinquent, Bankruptcies, Purpose, Term, Current Loan Amount, Current Credit Balance, Monthly Debt, Credit Score, Credit Default]
# Index: []

# %% [markdown]
# **Number of Credit Problems**

# %%
data['Number of Credit Problems'].value_counts()
# Out:
# 0.0     8644
# 1.0     1161
# 2.0      122
# 3.0       42
# 5.0       11
# 4.0       10
# 6.0        4
# 7.0        2
# 15.0       1
# Name: Number of Credit Problems, dtype: int64

# %%
# здесь все хорошо

# %% [markdown]
# **Months since last delinquent**

# %%
data['Months since last delinquent'].value_counts()
# Out:
# 14.0     104
# 16.0      91
# 33.0      90
# 29.0      90
# 13.0      90
#         ...
# 91.0       1
# 118.0      1
# 86.0       1
# 84.0       1
# 92.0       1
# Name: Months since last delinquent, Length: 89, dtype: int64

# %%
 data.loc[data['Months since last delinquent'] == 0]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 100        Own Home       337079.0               1 year        0.0
# 256            Rent       857660.0               1 year        0.0
# 257   Home Mortgage      1569040.0              2 years        0.0
# 898            Rent       739005.0              2 years        0.0
# 1404           Rent       349391.0             < 1 year        0.0
# 1501  Home Mortgage      1993440.0            10+ years        0.0
# 2890  Home Mortgage      1230193.0              7 years        0.0
# 3063           Rent       464474.0            10+ years        0.0
# 3252           Rent       832770.0             < 1 year        0.0
# 3496           Rent       233567.0               1 year        0.0
# 4938  Home Mortgage       862106.0              7 years        0.0
# 4995  Home Mortgage      3676063.0            10+ years        0.0
# 5523  Home Mortgage      1520304.0            10+ years        0.0
# 5566       Own Home       958960.0             < 1 year        0.0
# 5705  Home Mortgage      2716031.0            10+ years        0.0
# 6266  Home Mortgage      1331760.0            10+ years        0.0
# 7184           Rent       240122.0             < 1 year        0.0
# 7379       Own Home       290415.0             < 1 year        0.0
# 7676  Home Mortgage      3725900.0              5 years        0.0
# 7741  Home Mortgage      1525016.0            10+ years        0.0
# 7876           Rent       797520.0              2 years        0.0
# 8078  Home Mortgage      1721438.0            10+ years        0.0
# 8301  Home Mortgage      2914695.0              8 years        0.0
# 8834           Rent       645620.0            10+ years        0.0
# 9416  Home Mortgage      2109200.0            10+ years        0.0
# 9507           Rent      1414400.0              2 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 100                       9.0                     39.6             644204.0
# 256                       6.0                     19.7             291082.0
# 257                      15.0                     13.6            1556390.0
# 898                      20.0                     18.3            2177758.0
# 1404                      4.0                     12.7                  0.0
# 1501                     13.0                     13.4            1662936.0
# 2890                     13.0                     19.0             422884.0
# 3063                      5.0                     14.9              38126.0
# 3252                      7.0                     16.5             636856.0
# 3496                      7.0                     11.7                  0.0
# 4938                      3.0                     14.0             474694.0
# 4995                     16.0                     20.6             573276.0
# 5523                     21.0                     35.5           21372428.0
# 5566                     12.0                     24.7             594594.0
# 5705                     12.0                     15.0             867350.0
# 6266                      9.0                     28.5             875600.0
# 7184                      3.0                     12.9              11132.0
# 7379                     16.0                     12.5             116644.0
# 7676                     22.0                     27.5            5926250.0
# 7741                     20.0                     43.1            2600840.0
# 7876                     13.0                     18.2             417428.0
# 8078                     11.0                     14.5             589204.0
# 8301                     10.0                     20.3            1801118.0
# 8834                      6.0                     18.8             331320.0
# 9416                     14.0                     16.0             149666.0
# 9507                     15.0                      8.9             489038.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 100                         0.0                           0.0           NaN
# 256                         0.0                           0.0           NaN
# 257                         0.0                           0.0           NaN
# 898                         0.0                           0.0           NaN
# 1404                        0.0                           0.0           NaN
# 1501                        0.0                           0.0           0.0
# 2890                        0.0                           0.0           0.0
# 3063                        0.0                           0.0           NaN
# 3252                        0.0                           0.0           NaN
# 3496                        0.0                           0.0           NaN
# 4938                        0.0                           0.0           0.0
# 4995                        0.0                           0.0           0.0
# 5523                        0.0                           0.0           0.0
# 5566                        0.0                           0.0           NaN
# 5705                        0.0                           0.0           0.0
# 6266                        0.0                           0.0           0.0
# 7184                        0.0                           0.0           NaN
# 7379                        0.0                           0.0           NaN
# 7676                        0.0                           0.0           0.0
# 7741                        0.0                           0.0           NaN
# 7876                        0.0                           0.0           NaN
# 8078                        0.0                           0.0           0.0
# 8301                        0.0                           0.0           NaN
# 8834                        1.0                           0.0           1.0
# 9416                        0.0                           0.0           0.0
# 9507                        0.0                           0.0           0.0
#
#                    Purpose        Term  Current Loan Amount  \
# 100   educational expenses  Short Term           99999999.0
# 256     debt consolidation  Short Term           99999999.0
# 257     debt consolidation  Short Term             447480.0
# 898     debt consolidation  Short Term             456808.0
# 1404                 other  Short Term              11242.0
# 1501    debt consolidation  Short Term              65582.0
# 2890    debt consolidation  Short Term             394460.0
# 3063                 other  Short Term              44814.0
# 3252         business loan  Short Term             156970.0
# 3496  educational expenses  Short Term             210166.0
# 4938    debt consolidation  Short Term              26048.0
# 4995     home improvements  Short Term             112024.0
# 5523                 other   Long Term           99999999.0
# 5566                 other  Short Term              92620.0
# 5705    debt consolidation  Short Term             436788.0
# 6266    debt consolidation  Short Term             137676.0
# 7184    debt consolidation  Short Term              46706.0
# 7379        small business  Short Term              71170.0
# 7676    debt consolidation   Long Term             754996.0
# 7741     home improvements  Short Term             110374.0
# 7876    debt consolidation  Short Term             217800.0
# 8078    debt consolidation  Short Term             150810.0
# 8301    debt consolidation  Short Term             539990.0
# 8834    debt consolidation  Short Term              96184.0
# 9416    debt consolidation   Long Term             333234.0
# 9507    debt consolidation  Short Term              80014.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 100                 224770.0        4326.0         734.0             0.0
# 256                 236816.0        3488.0         743.0             0.0
# 257                 524210.0       19613.0           NaN             0.0
# 898                 607487.0        9669.0         732.0             1.0
# 1404                     0.0        1243.0         747.0             0.0
# 1501                465329.0       24918.0           NaN             0.0
# 2890                301663.0       20913.0         734.0             0.0
# 3063                 18373.0         929.0        7490.0             1.0
# 3252                 52250.0        1145.0         750.0             0.0
# 3496                     0.0           0.0         746.0             0.0
# 4938                 55347.0        3096.0         743.0             0.0
# 4995                390146.0       33085.0         731.0             1.0
# 5523               1975012.0       12555.0         728.0             0.0
# 5566                126331.0       11987.0           NaN             0.0
# 5705                448685.0       29424.0         728.0             0.0
# 6266                443878.0       16647.0           NaN             1.0
# 7184                  8797.0        2881.0        7060.0             1.0
# 7379                 55499.0        2953.0        7160.0             1.0
# 7676               3209062.0       69550.0         686.0             NaN
# 7741                159486.0        4766.0         748.0             NaN
# 7876                275443.0        9969.0           NaN             NaN
# 8078                118560.0       22522.0         739.0             NaN
# 8301                 90212.0         534.0         742.0             NaN
# 8834                 70965.0       17055.0         683.0             NaN
# 9416                  9823.0       26365.0           NaN             NaN
# 9507                 21109.0       17680.0           NaN             NaN

# %%
data["Months since last delinquent"].isnull().sum()
# Out:
# 5437

# %%
data.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0            10+ years        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                           NaN           1.0
# 1                        0.0                           NaN           0.0
# 2                        0.0                           NaN           0.0
# 3                        1.0                           NaN           1.0
# 4                        1.0                           NaN           0.0
#
#               Purpose        Term  Current Loan Amount  \
# 0  debt consolidation  Short Term           99999999.0
# 1  debt consolidation   Long Term             264968.0
# 2  debt consolidation  Short Term           99999999.0
# 3  debt consolidation  Short Term             121396.0
# 4  debt consolidation  Short Term             125840.0
#
#    Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                 47386.0        7914.0         749.0             0.0
# 1                394972.0       18373.0         737.0             1.0
# 2                308389.0       13651.0         742.0             0.0
# 3                 95855.0       11338.0         694.0             0.0
# 4                 93309.0        7180.0         719.0             0.0

# %%
# предположим, что отсутствие данных - это отсутствие просрочек, и заменим на большое число месяцев
data.loc[data["Months since last delinquent"].isnull(), 'Months since last delinquent'] = 1000000000

# %%
#так же поступим с нулевыми значениями (не привело к улучшению модели)
#data.loc[data['Months since last delinquent'] == 0, 'Months since last delinquent'] = 1000000000

# %% [markdown]
# **Bankruptcies**

# %%
data['Bankruptcies'].value_counts()
# Out:
# 0.0    8909
# 1.0    1020
# 2.0      36
# 3.0      10
# 4.0       3
# 5.0       2
# Name: Bankruptcies, dtype: int64

# %%
data.loc[(data["Bankruptcies"]>= 4, "Bankruptcies")] = data["Bankruptcies"].median()

# %%
data["Bankruptcies"].isnull().sum()
# Out:
# 17

# %%
data.loc[(data["Bankruptcies"].isnull())]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 100        Own Home       337079.0               1 year        0.0
# 256            Rent       857660.0               1 year        0.0
# 257   Home Mortgage      1569040.0              2 years        0.0
# 898            Rent       739005.0              2 years        0.0
# 1404           Rent       349391.0             < 1 year        0.0
# 3063           Rent       464474.0            10+ years        0.0
# 3252           Rent       832770.0             < 1 year        0.0
# 3351  Home Mortgage      2226192.0              8 years        0.0
# 3401           Rent       326154.0              6 years        0.0
# 3496           Rent       233567.0               1 year        0.0
# 4334           Rent       772749.0             < 1 year        0.0
# 5566       Own Home       958960.0             < 1 year        0.0
# 7184           Rent       240122.0             < 1 year        0.0
# 7379       Own Home       290415.0             < 1 year        0.0
# 7741  Home Mortgage      1525016.0            10+ years        0.0
# 7876           Rent       797520.0              2 years        0.0
# 8301  Home Mortgage      2914695.0              8 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 100                       9.0                     39.6             644204.0
# 256                       6.0                     19.7             291082.0
# 257                      15.0                     13.6            1556390.0
# 898                      20.0                     18.3            2177758.0
# 1404                      4.0                     12.7                  0.0
# 3063                      5.0                     14.9              38126.0
# 3252                      7.0                     16.5             636856.0
# 3351                     14.0                     23.3             792836.0
# 3401                      2.0                     19.1                  0.0
# 3496                      7.0                     11.7                  0.0
# 4334                      9.0                     19.6             575124.0
# 5566                     12.0                     24.7             594594.0
# 7184                      3.0                     12.9              11132.0
# 7379                     16.0                     12.5             116644.0
# 7741                     20.0                     43.1            2600840.0
# 7876                     13.0                     18.2             417428.0
# 8301                     10.0                     20.3            1801118.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 100                         0.0                           0.0           NaN
# 256                         0.0                           0.0           NaN
# 257                         0.0                           0.0           NaN
# 898                         0.0                           0.0           NaN
# 1404                        0.0                           0.0           NaN
# 3063                        0.0                           0.0           NaN
# 3252                        0.0                           0.0           NaN
# 3351                        0.0                          73.0           NaN
# 3401                        0.0                          77.0           NaN
# 3496                        0.0                           0.0           NaN
# 4334                        0.0                          19.0           NaN
# 5566                        0.0                           0.0           NaN
# 7184                        0.0                           0.0           NaN
# 7379                        0.0                           0.0           NaN
# 7741                        0.0                           0.0           NaN
# 7876                        0.0                           0.0           NaN
# 8301                        0.0                           0.0           NaN
#
#                    Purpose        Term  Current Loan Amount  \
# 100   educational expenses  Short Term           99999999.0
# 256     debt consolidation  Short Term           99999999.0
# 257     debt consolidation  Short Term             447480.0
# 898     debt consolidation  Short Term             456808.0
# 1404                 other  Short Term              11242.0
# 3063                 other  Short Term              44814.0
# 3252         business loan  Short Term             156970.0
# 3351    debt consolidation  Short Term             528968.0
# 3401                 other  Short Term           99999999.0
# 3496  educational expenses  Short Term             210166.0
# 4334    debt consolidation  Short Term             167882.0
# 5566                 other  Short Term              92620.0
# 7184    debt consolidation  Short Term              46706.0
# 7379        small business  Short Term              71170.0
# 7741     home improvements  Short Term             110374.0
# 7876    debt consolidation  Short Term             217800.0
# 8301    debt consolidation  Short Term             539990.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 100                 224770.0        4326.0         734.0             0.0
# 256                 236816.0        3488.0         743.0             0.0
# 257                 524210.0       19613.0           NaN             0.0
# 898                 607487.0        9669.0         732.0             1.0
# 1404                     0.0        1243.0         747.0             0.0
# 3063                 18373.0         929.0        7490.0             1.0
# 3252                 52250.0        1145.0         750.0             0.0
# 3351                625157.0       23746.0         674.0             0.0
# 3401                     0.0        1245.0         712.0             0.0
# 3496                     0.0           0.0         746.0             0.0
# 4334                152988.0        7792.0         729.0             0.0
# 5566                126331.0       11987.0           NaN             0.0
# 7184                  8797.0        2881.0        7060.0             1.0
# 7379                 55499.0        2953.0        7160.0             1.0
# 7741                159486.0        4766.0         748.0             NaN
# 7876                275443.0        9969.0           NaN             NaN
# 8301                 90212.0         534.0         742.0             NaN

# %%
data.loc[data["Bankruptcies"].isnull(), 'Bankruptcies'] = data['Bankruptcies'].mode()[0]

# %%
data["Bankruptcies"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Purpose**

# %%
data['Purpose'].value_counts()
# Out:
# debt consolidation      7916
# other                    904
# home improvements        552
# business loan            159
# buy a car                130
# medical bills             98
# buy house                 53
# take a trip               50
# major purchase            49
# small business            31
# wedding                   17
# educational expenses      13
# moving                    12
# vacation                  11
# renewable energy           2
# Name: Purpose, dtype: int64

# %%
data["Purpose"].isnull().sum()
# Out:
# 0

# %%
# заменим renewable energy на моду для более удобного деления на фолды
data.replace({'Purpose': {'renewable energy':data['Purpose'].mode()[0]}}, inplace=True)

# %%
data['Purpose'].value_counts()
# Out:
# debt consolidation      7918
# other                    904
# home improvements        552
# business loan            159
# buy a car                130
# medical bills             98
# buy house                 53
# take a trip               50
# major purchase            49
# small business            31
# wedding                   17
# educational expenses      13
# moving                    12
# vacation                  11
# Name: Purpose, dtype: int64

# %% [markdown]
# **Term**

# %%
data['Term'].value_counts()
# Out:
# Short Term    7414
# Long Term     2583
# Name: Term, dtype: int64

# %%
# все хорошо

# %%
data.describe()
# Out:
#        Annual Income    Tax Liens  Number of Open Accounts  \
# count   9.997000e+03  9997.000000              9997.000000
# mean    1.388913e+06     0.031409                11.143443
# std     8.828508e+05     0.304386                 4.895101
# min     0.000000e+00     0.000000                 1.000000
# 25%     8.418400e+05     0.000000                 8.000000
# 50%     1.206348e+06     0.000000                10.000000
# 75%     1.706751e+06     0.000000                14.000000
# max     1.497561e+07    15.000000                48.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              9997.000000         9.997000e+03
# mean                 18.317235         6.916863e+05
# std                   7.093686         1.330128e+06
# min                   3.900000         0.000000e+00
# 25%                  13.500000         2.786960e+05
# 50%                  17.000000         4.781480e+05
# 75%                  22.000000         7.942660e+05
# max                  57.700000         5.756256e+07
#
#        Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# count                9997.000000                  9.997000e+03   9997.000000
# mean                    0.167950                  5.438632e+08      0.112234
# std                     0.514594                  4.980972e+08      0.335935
# min                     0.000000                  0.000000e+00      0.000000
# 25%                     0.000000                  3.500000e+01      0.000000
# 50%                     0.000000                  1.000000e+09      0.000000
# 75%                     0.000000                  1.000000e+09      0.000000
# max                    15.000000                  1.000000e+09      3.000000
#
#        Current Loan Amount  Current Credit Balance   Monthly Debt  \
# count         9.997000e+03            9.997000e+03    9997.000000
# mean          1.194734e+07            2.911997e+05   18303.154446
# std           3.201294e+07            3.335666e+05   11831.623158
# min           1.124200e+04            0.000000e+00       0.000000
# 25%           1.806200e+05            1.131830e+05   10060.000000
# 50%           3.117400e+05            2.088860e+05   16199.000000
# 75%           5.210480e+05            3.616270e+05   23888.000000
# max           1.000000e+08            6.506797e+06  136679.000000
#
#        Credit Score  Credit Default
# count   7928.000000     7497.000000
# mean    1172.101287        0.281846
# std     1640.005402        0.449929
# min      585.000000        0.000000
# 25%      711.000000        0.000000
# 50%      731.000000        0.000000
# 75%      743.000000        1.000000
# max     7510.000000        1.000000

# %% [markdown]
# **Current Loan Amount**

# %%
data['Current Loan Amount'].value_counts()
# Out:
# 99999999.0    1167
# 270226.0         6
# 223322.0         6
# 218064.0         6
# 89298.0          6
#               ...
# 365508.0         1
# 56012.0          1
# 652740.0         1
# 248292.0         1
# 33792.0          1
# Name: Current Loan Amount, Length: 6783, dtype: int64

# %%
data["Current Loan Amount"].isnull().sum()
# Out:
# 0

# %%
data.loc[data['Current Loan Amount'] == 0]
# Out:
# Empty DataFrame
# Columns: [Home Ownership, Annual Income, Years in current job, Tax Liens, Number of Open Accounts, Years of Credit History, Maximum Open Credit, Number of Credit Problems, Months since last delinquent, Bankruptcies, Purpose, Term, Current Loan Amount, Current Credit Balance, Monthly Debt, Credit Score, Credit Default]
# Index: []

# %%
data['Current Loan Amount'].max()
# Out:
# 99999999.0

# %%
#это ошибка в данных скорее всего
data.loc[data['Current Loan Amount'] > 10000000]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0          Own Home       482087.0            10+ years        0.0
# 2     Home Mortgage       751412.0              8 years        0.0
# 6     Home Mortgage      1511108.0            10+ years        0.0
# 22             Rent       463790.0            10+ years        0.0
# 27             Rent      1004055.0              8 years        0.0
# ...             ...            ...                  ...        ...
# 9944           Rent      5997920.0              2 years        0.0
# 9957  Home Mortgage      1437502.0            10+ years        0.0
# 9961           Rent       613225.0              3 years        0.0
# 9967  Home Mortgage       939075.0              4 years        0.0
# 9995  Home Mortgage      1020053.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 2                        11.0                     35.0            1182434.0
# 6                         9.0                     20.3             388124.0
# 22                        6.0                     28.3             288442.0
# 27                        7.0                     14.5             328394.0
# ...                       ...                      ...                  ...
# 9944                     11.0                     17.6            1178584.0
# 9957                     16.0                     13.0             750970.0
# 9961                      6.0                     16.8             188078.0
# 9967                     21.0                     16.7             577940.0
# 9995                     14.0                     29.1             559152.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                  1.000000e+09           1.0
# 2                           0.0                  1.000000e+09           0.0
# 6                           0.0                  7.300000e+01           0.0
# 22                          0.0                  1.000000e+09           0.0
# 27                          0.0                  1.000000e+09           0.0
# ...                         ...                           ...           ...
# 9944                        0.0                  4.600000e+01           0.0
# 9957                        1.0                  1.000000e+09           1.0
# 9961                        0.0                  1.000000e+09           0.0
# 9967                        0.0                  1.000000e+09           0.0
# 9995                        1.0                  6.800000e+01           1.0
#
#                  Purpose        Term  Current Loan Amount  \
# 0     debt consolidation  Short Term           99999999.0
# 2     debt consolidation  Short Term           99999999.0
# 6      home improvements  Short Term           99999999.0
# 22    debt consolidation  Short Term           99999999.0
# 27    debt consolidation  Short Term           99999999.0
# ...                  ...         ...                  ...
# 9944  debt consolidation  Short Term           99999999.0
# 9957  debt consolidation  Short Term           99999999.0
# 9961               other  Short Term           99999999.0
# 9967  debt consolidation  Short Term           99999999.0
# 9995  debt consolidation  Short Term           99999999.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                    47386.0        7914.0         749.0             0.0
# 2                   308389.0       13651.0         742.0             0.0
# 6                    51623.0        2317.0         745.0             0.0
# 22                  157700.0        5063.0         738.0             0.0
# 27                  195966.0        6041.0         734.0             0.0
# ...                      ...           ...           ...             ...
# 9944                350151.0       39686.0         750.0             NaN
# 9957                 71991.0       25396.0         747.0             NaN
# 9961                 13319.0        7665.0         749.0             NaN
# 9967                269534.0       17216.0         737.0             NaN
# 9995                162735.0       15046.0         745.0             NaN
#
# [1167 rows x 17 columns]

# %%
# заменим на медиану
data.loc[data["Current Loan Amount"] > 10000000, 'Current Loan Amount'] = data['Current Loan Amount'].median()

# %%
data['Current Loan Amount'].value_counts()
# Out:
# 311740.0    1168
# 270226.0       6
# 218064.0       6
# 89298.0        6
# 223322.0       6
#             ...
# 365508.0       1
# 56012.0        1
# 652740.0       1
# 248292.0       1
# 33792.0        1
# Name: Current Loan Amount, Length: 6782, dtype: int64

# %% [markdown]
# **Current Credit Balance**

# %%
# Current Credit Balance
data['Current Credit Balance'].value_counts()
# Out:
# 0.0         64
# 169917.0     5
# 191710.0     5
# 293094.0     5
# 136401.0     5
#             ..
# 205200.0     1
# 195586.0     1
# 567568.0     1
# 616721.0     1
# 1824.0       1
# Name: Current Credit Balance, Length: 8454, dtype: int64

# %%
data["Current Credit Balance"].isnull().sum()
# Out:
# 0

# %%
# c Current Credit Balance все ок, думаю, что ноль здесь может быть

# %% [markdown]
# **Monthly Debt**

# %%
data['Monthly Debt'].value_counts()
# Out:
# 0.0        6
# 19667.0    4
# 13565.0    4
# 13162.0    4
# 19222.0    4
#           ..
# 24710.0    1
# 9811.0     1
# 2931.0     1
# 16286.0    1
# 17.0       1
# Name: Monthly Debt, Length: 8675, dtype: int64

# %%
data["Monthly Debt"].isnull().sum()
# Out:
# 0

# %%
# c Monthly Debt все ок

# %% [markdown]
# **Credit Score**

# %%
data['Credit Score'].value_counts()
# Out:
# 740.0     219
# 747.0     217
# 741.0     205
# 748.0     201
# 745.0     201
#          ...
# 6710.0      1
# 6600.0      1
# 6680.0      1
# 620.0       1
# 6110.0      1
# Name: Credit Score, Length: 278, dtype: int64

# %%
# по describe максимум выглядит выбросом, посмотрим
# credit score обычно максимум 850 или 900
data.loc[(data["Credit Score"] > 900)]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 69    Home Mortgage      1408527.0              2 years        0.0
# 87    Home Mortgage      1533566.0              7 years        0.0
# 94             Rent      1049294.0              3 years        0.0
# 96             Rent       757568.0              5 years        0.0
# 116   Home Mortgage      1039984.0            10+ years        0.0
# ...             ...            ...                  ...        ...
# 9949  Home Mortgage      1030902.0            10+ years        0.0
# 9970  Home Mortgage      1116972.0              8 years        0.0
# 9972  Home Mortgage      1951110.0             < 1 year        0.0
# 9977           Rent       667603.0              2 years        0.0
# 9999           Rent      1694439.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 69                       12.0                     17.5             700062.0
# 87                       11.0                     14.8             715462.0
# 94                        5.0                      6.1             249810.0
# 96                       13.0                     11.4             383548.0
# 116                      10.0                     23.8             147950.0
# ...                       ...                      ...                  ...
# 9949                     14.0                     25.8             871838.0
# 9970                      8.0                     14.0             351560.0
# 9972                     13.0                     24.1             440506.0
# 9977                      5.0                     12.3             333366.0
# 9999                     12.0                     18.4            1199748.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 69                          0.0                  2.100000e+01           0.0
# 87                          0.0                  1.900000e+01           0.0
# 94                          0.0                  1.000000e+09           0.0
# 96                          0.0                  1.000000e+09           0.0
# 116                         0.0                  6.300000e+01           0.0
# ...                         ...                           ...           ...
# 9949                        0.0                  1.000000e+09           0.0
# 9970                        0.0                  1.000000e+09           0.0
# 9972                        1.0                  1.000000e+09           1.0
# 9977                        0.0                  1.000000e+09           0.0
# 9999                        1.0                  7.200000e+01           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 69                 other   Long Term             525998.0
# 87    debt consolidation  Short Term             210826.0
# 94         business loan  Short Term             337502.0
# 96    debt consolidation  Short Term             210518.0
# 116   debt consolidation  Short Term             224246.0
# ...                  ...         ...                  ...
# 9949  debt consolidation   Long Term             533346.0
# 9970  debt consolidation   Long Term             258676.0
# 9972  debt consolidation  Short Term             129096.0
# 9977  debt consolidation  Short Term             220858.0
# 9999  debt consolidation   Long Term             763004.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 69                  174135.0        9320.0        6470.0             1.0
# 87                  285475.0       18147.0        7440.0             1.0
# 94                  119529.0       15215.0        7010.0             1.0
# 96                  276583.0       11553.0        7320.0             1.0
# 116                  95456.0       13780.0        7390.0             1.0
# ...                      ...           ...           ...             ...
# 9949                430692.0       27319.0        7300.0             NaN
# 9970                239552.0       14521.0        6470.0             NaN
# 9972                 92454.0       25852.0        7410.0             NaN
# 9977                152589.0        7622.0        7480.0             NaN
# 9999                559531.0       23440.0        6820.0             NaN
#
# [560 rows x 17 columns]

# %%
 # скорее всего здесь ошибка, разделим их на 10
data.loc[(data['Credit Score'] > 900), 'Credit Score'] = data.loc[(data['Credit Score'] > 900), 'Credit Score'] / 10

# %%
data.loc[(data["Credit Score"] > 900)]
# Out:
# Empty DataFrame
# Columns: [Home Ownership, Annual Income, Years in current job, Tax Liens, Number of Open Accounts, Years of Credit History, Maximum Open Credit, Number of Credit Problems, Months since last delinquent, Bankruptcies, Purpose, Term, Current Loan Amount, Current Credit Balance, Monthly Debt, Credit Score, Credit Default]
# Index: []

# %%
data["Credit Score"].isnull().sum()
# Out:
# 2069

# %%
data.loc[(data["Credit Score"].isnull())].head()
# Out:
#    Home Ownership  Annual Income Years in current job  Tax Liens  \
# 5            Rent      1495360.0              7 years        0.0
# 8   Home Mortgage         1360.0              5 years        0.0
# 9   Home Mortgage      1409040.0               1 year        0.0
# 10  Home Mortgage      1167360.0             < 1 year        0.0
# 16           Rent      1507520.0              7 years        0.0
#
#     Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 5                      12.0                     14.6             366784.0
# 8                      17.0                     15.7                  0.0
# 9                      10.0                     24.6             511302.0
# 10                      7.0                     11.5             256322.0
# 16                      6.0                     17.8             899492.0
#
#     Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 5                         0.0                  1.000000e+09           0.0
# 8                         1.0                  1.000000e+09           1.0
# 9                         0.0                  6.000000e+00           0.0
# 10                        0.0                  1.000000e+09           0.0
# 16                        0.0                  1.000000e+09           0.0
#
#                Purpose        Term  Current Loan Amount  \
# 5                other   Long Term             337304.0
# 8    home improvements  Short Term             129734.0
# 9   debt consolidation   Long Term             572880.0
# 10  debt consolidation  Short Term             220858.0
# 16  debt consolidation   Long Term             313038.0
#
#     Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 5                 165680.0       18692.0           NaN             1.0
# 8                     19.0          17.0           NaN             0.0
# 9                 205333.0       17613.0           NaN             1.0
# 10                187492.0       14592.0           NaN             0.0
# 16                538346.0       18844.0           NaN             1.0

# %%
# заменим на моду
data.loc[data["Credit Score"].isnull(), 'Credit Score'] = data['Credit Score'].mode()[0]

# %% [markdown]
# ## Работа с категориальными признаками

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9997 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                9997 non-null   object
#  1   Annual Income                 9997 non-null   float64
#  2   Years in current job          9997 non-null   object
#  3   Tax Liens                     9997 non-null   float64
#  4   Number of Open Accounts       9997 non-null   float64
#  5   Years of Credit History       9997 non-null   float64
#  6   Maximum Open Credit           9997 non-null   float64
#  7   Number of Credit Problems     9997 non-null   float64
#  8   Months since last delinquent  9997 non-null   float64
#  9   Bankruptcies                  9997 non-null   float64
#  10  Purpose                       9997 non-null   object
#  11  Term                          9997 non-null   object
#  12  Current Loan Amount           9997 non-null   float64
#  13  Current Credit Balance        9997 non-null   float64
#  14  Monthly Debt                  9997 non-null   float64
#  15  Credit Score                  9997 non-null   float64
#  16  Credit Default                7497 non-null   float64
# dtypes: float64(13), object(4)
# memory usage: 1.4+ MB

# %%
for cat_colname in data.select_dtypes(include='object').columns[0:]:
    data = pd.concat([data, pd.get_dummies(data[cat_colname], prefix=cat_colname)], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9997 entries, 0 to 9999
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Home Ownership                  9997 non-null   object
#  1   Annual Income                   9997 non-null   float64
#  2   Years in current job            9997 non-null   object
#  3   Tax Liens                       9997 non-null   float64
#  4   Number of Open Accounts         9997 non-null   float64
#  5   Years of Credit History         9997 non-null   float64
#  6   Maximum Open Credit             9997 non-null   float64
#  7   Number of Credit Problems       9997 non-null   float64
#  8   Months since last delinquent    9997 non-null   float64
#  9   Bankruptcies                    9997 non-null   float64
#  10  Purpose                         9997 non-null   object
#  11  Term                            9997 non-null   object
#  12  Current Loan Amount             9997 non-null   float64
#  13  Current Credit Balance          9997 non-null   float64
#  14  Monthly Debt                    9997 non-null   float64
#  15  Credit Score                    9997 non-null   float64
#  16  Credit Default                  7497 non-null   float64
#  17  Home Ownership_Have Mortgage    9997 non-null   uint8
#  18  Home Ownership_Home Mortgage    9997 non-null   uint8
#  19  Home Ownership_Own Home         9997 non-null   uint8
#  20  Home Ownership_Rent             9997 non-null   uint8
#  21  Years in current job_1 year     9997 non-null   uint8
#  22  Years in current job_10+ years  9997 non-null   uint8
#  23  Years in current job_2 years    9997 non-null   uint8
#  24  Years in current job_3 years    9997 non-null   uint8
#  25  Years in current job_4 years    9997 non-null   uint8
#  26  Years in current job_5 years    9997 non-null   uint8
#  27  Years in current job_6 years    9997 non-null   uint8
#  28  Years in current job_7 years    9997 non-null   uint8
#  29  Years in current job_8 years    9997 non-null   uint8
#  30  Years in current job_9 years    9997 non-null   uint8
#  31  Years in current job_< 1 year   9997 non-null   uint8
#  32  Purpose_business loan           9997 non-null   uint8
#  33  Purpose_buy a car               9997 non-null   uint8
#  34  Purpose_buy house               9997 non-null   uint8
#  35  Purpose_debt consolidation      9997 non-null   uint8
#  36  Purpose_educational expenses    9997 non-null   uint8
#  37  Purpose_home improvements       9997 non-null   uint8
#  38  Purpose_major purchase          9997 non-null   uint8
#  39  Purpose_medical bills           9997 non-null   uint8
#  40  Purpose_moving                  9997 non-null   uint8
#  41  Purpose_other                   9997 non-null   uint8
#  42  Purpose_small business          9997 non-null   uint8
#  43  Purpose_take a trip             9997 non-null   uint8
#  44  Purpose_vacation                9997 non-null   uint8
#  45  Purpose_wedding                 9997 non-null   uint8
#  46  Term_Long Term                  9997 non-null   uint8
#  47  Term_Short Term                 9997 non-null   uint8
# dtypes: float64(13), object(4), uint8(31)
# memory usage: 1.7+ MB

# %% [markdown]
# **Добавление новых признаков**

# %%
data['annual_income_bigger_than_mean'] = np.where(
    data["Annual Income"] > data["Annual Income"].mean(), 1, 0)

# %%
data.loc[data["Monthly Debt"] == 0, 'Monthly Debt'] = 1
data['ratio_ann_income/monthlydebt_'] =  data['Annual Income'] / data['Monthly Debt']

# %%
data["ratio_ann_income/monthlydebt_"].describe()
# Out:
# count    9.997000e+03
# mean     3.454041e+02
# std      1.543389e+04
# min      0.000000e+00
# 25%      5.714322e+01
# 50%      8.000000e+01
# 75%      9.375131e+01
# max      1.254513e+06
# Name: ratio_ann_income/monthlydebt_, dtype: float64

# %%
gp = data.groupby(["Years in current job"])["Annual Income"].mean()
data["Mean_income_by_Years in current job"] = data["Years in current job"].map(gp.to_dict())

data["diff_Annual Income_and_mean_Annual Income_by_Years in current job"] = data["Annual Income"] - data["Mean_income_by_Years in current job"]
data["ratio_Annual Income_and_mean_Annual Income_by_Years in current job"] = data["Annual Income"] / data["Mean_income_by_Years in current job"] - 1

# %%
data['Credit Score_changed'] = np.where(
    data["Credit Score"] == data['Credit Score'].mode()[0], 1, 0)

# %% [markdown]
# ### Стандартизация признаков

# %%
data.columns.tolist()
# Out:
# ['Home Ownership',
#  'Annual Income',
#  'Years in current job',
#  'Tax Liens',
#  'Number of Open Accounts',
#  'Years of Credit History',
#  'Maximum Open Credit',
#  'Number of Credit Problems',
#  'Months since last delinquent',
#  'Bankruptcies',
#  'Purpose',
#  'Term',
#  'Current Loan Amount',
#  'Current Credit Balance',
#  'Monthly Debt',
#  'Credit Score',
#  'Credit Default',
#  'Home Ownership_Have Mortgage',
#  'Home Ownership_Home Mortgage',
#  'Home Ownership_Own Home',
#  'Home Ownership_Rent',
#  'Years in current job_1 year',
#  'Years in current job_10+ years',
#  'Years in current job_2 years',
#  'Years in current job_3 years',
#  'Years in current job_4 years',
#  'Years in current job_5 years',
#  'Years in current job_6 years',
#  'Years in current job_7 years',
#  'Years in current job_8 years',
#  'Years in current job_9 years',
#  'Years in current job_< 1 year',
#  'Purpose_business loan',
#  'Purpose_buy a car',
#  'Purpose_buy house',
#  'Purpose_debt consolidation',
#  'Purpose_educational expenses',
#  'Purpose_home improvements',
#  'Purpose_major purchase',
#  'Purpose_medical bills',
#  'Purpose_moving',
#  'Purpose_other',
#  'Purpose_small business',
#  'Purpose_take a trip',
#  'Purpose_vacation',
#  'Purpose_wedding',
#  'Term_Long Term',
#  'Term_Short Term',
#  'annual_income_bigger_than_mean',
#  'ratio_ann_income/monthlydebt_',
#  'Mean_income_by_Years in current job',
#  'diff_Annual Income_and_mean_Annual Income_by_Years in current job',
#  'ratio_Annual Income_and_mean_Annual Income_by_Years in current job',
#  'Credit Score_changed']

# %%
feature_names_for_stand = [
 'Annual Income',
 'Tax Liens',
 'Number of Open Accounts',
 'Years of Credit History',
 'Maximum Open Credit',
 'Number of Credit Problems',
 'Months since last delinquent',
 'Bankruptcies',
 'Current Loan Amount',
 'Current Credit Balance',
 'Monthly Debt',
 'Credit Score',
'ratio_ann_income/monthlydebt_',
'Mean_income_by_Years in current job',
 'diff_Annual Income_and_mean_Annual Income_by_Years in current job',
 'ratio_Annual Income_and_mean_Annual Income_by_Years in current job'
]
data[feature_names_for_stand].dtypes
# Out:
# Annual Income                                                         float64
# Tax Liens                                                             float64
# Number of Open Accounts                                               float64
# Years of Credit History                                               float64
# Maximum Open Credit                                                   float64
# Number of Credit Problems                                             float64
# Months since last delinquent                                          float64
# Bankruptcies                                                          float64
# Current Loan Amount                                                   float64
# Current Credit Balance                                                float64
# Monthly Debt                                                          float64
# Credit Score                                                          float64
# ratio_ann_income/monthlydebt_                                         float64
# Mean_income_by_Years in current job                                   float64
# diff_Annual Income_and_mean_Annual Income_by_Years in current job     float64
# ratio_Annual Income_and_mean_Annual Income_by_Years in current job    float64
# dtype: object

# %%
scaler = StandardScaler()

data_norm = data.copy()
data_norm[feature_names_for_stand] = scaler.fit_transform(data_norm[feature_names_for_stand])

data = data_norm.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9997 entries, 0 to 9999
# Data columns (total 54 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Home Ownership                                                      9997 non-null   object
#  1   Annual Income                                                       9997 non-null   float64
#  2   Years in current job                                                9997 non-null   object
#  3   Tax Liens                                                           9997 non-null   float64
#  4   Number of Open Accounts                                             9997 non-null   float64
#  5   Years of Credit History                                             9997 non-null   float64
#  6   Maximum Open Credit                                                 9997 non-null   float64
#  7   Number of Credit Problems                                           9997 non-null   float64
#  8   Months since last delinquent                                        9997 non-null   float64
#  9   Bankruptcies                                                        9997 non-null   float64
#  10  Purpose                                                             9997 non-null   object
#  11  Term                                                                9997 non-null   object
#  12  Current Loan Amount                                                 9997 non-null   float64
#  13  Current Credit Balance                                              9997 non-null   float64
#  14  Monthly Debt                                                        9997 non-null   float64
#  15  Credit Score                                                        9997 non-null   float64
#  16  Credit Default                                                      7497 non-null   float64
#  17  Home Ownership_Have Mortgage                                        9997 non-null   uint8
#  18  Home Ownership_Home Mortgage                                        9997 non-null   uint8
#  19  Home Ownership_Own Home                                             9997 non-null   uint8
#  20  Home Ownership_Rent                                                 9997 non-null   uint8
#  21  Years in current job_1 year                                         9997 non-null   uint8
#  22  Years in current job_10+ years                                      9997 non-null   uint8
#  23  Years in current job_2 years                                        9997 non-null   uint8
#  24  Years in current job_3 years                                        9997 non-null   uint8
#  25  Years in current job_4 years                                        9997 non-null   uint8
#  26  Years in current job_5 years                                        9997 non-null   uint8
#  27  Years in current job_6 years                                        9997 non-null   uint8
#  28  Years in current job_7 years                                        9997 non-null   uint8
#  29  Years in current job_8 years                                        9997 non-null   uint8
#  30  Years in current job_9 years                                        9997 non-null   uint8
#  31  Years in current job_< 1 year                                       9997 non-null   uint8
#  32  Purpose_business loan                                               9997 non-null   uint8
#  33  Purpose_buy a car                                                   9997 non-null   uint8
#  34  Purpose_buy house                                                   9997 non-null   uint8
#  35  Purpose_debt consolidation                                          9997 non-null   uint8
#  36  Purpose_educational expenses                                        9997 non-null   uint8
#  37  Purpose_home improvements                                           9997 non-null   uint8
#  38  Purpose_major purchase                                              9997 non-null   uint8
#  39  Purpose_medical bills                                               9997 non-null   uint8
#  40  Purpose_moving                                                      9997 non-null   uint8
#  41  Purpose_other                                                       9997 non-null   uint8
#  42  Purpose_small business                                              9997 non-null   uint8
#  43  Purpose_take a trip                                                 9997 non-null   uint8
#  44  Purpose_vacation                                                    9997 non-null   uint8
#  45  Purpose_wedding                                                     9997 non-null   uint8
#  46  Term_Long Term                                                      9997 non-null   uint8
#  47  Term_Short Term                                                     9997 non-null   uint8
#  48  annual_income_bigger_than_mean                                      9997 non-null   int64
#  49  ratio_ann_income/monthlydebt_                                       9997 non-null   float64
#  50  Mean_income_by_Years in current job                                 9997 non-null   float64
#  51  diff_Annual Income_and_mean_Annual Income_by_Years in current job   9997 non-null   float64
#  52  ratio_Annual Income_and_mean_Annual Income_by_Years in current job  9997 non-null   float64
#  53  Credit Score_changed                                                9997 non-null   int64
# dtypes: float64(17), int64(2), object(4), uint8(31)
# memory usage: 2.1+ MB

# %%
data.std()
# Out:
# Annual Income                                                         1.000050
# Tax Liens                                                             1.000050
# Number of Open Accounts                                               1.000050
# Years of Credit History                                               1.000050
# Maximum Open Credit                                                   1.000050
# Number of Credit Problems                                             1.000050
# Months since last delinquent                                          1.000050
# Bankruptcies                                                          1.000050
# Current Loan Amount                                                   1.000050
# Current Credit Balance                                                1.000050
# Monthly Debt                                                          1.000050
# Credit Score                                                          1.000050
# Credit Default                                                        0.449929
# Home Ownership_Have Mortgage                                          0.042397
# Home Ownership_Home Mortgage                                          0.499833
# Home Ownership_Own Home                                               0.285517
# Home Ownership_Rent                                                   0.493986
# Years in current job_1 year                                           0.247804
# Years in current job_10+ years                                        0.479968
# Years in current job_2 years                                          0.288655
# Years in current job_3 years                                          0.278487
# Years in current job_4 years                                          0.241383
# Years in current job_5 years                                          0.252650
# Years in current job_6 years                                          0.230544
# Years in current job_7 years                                          0.225270
# Years in current job_8 years                                          0.206464
# Years in current job_9 years                                          0.185827
# Years in current job_< 1 year                                         0.266641
# Purpose_business loan                                                 0.125113
# Purpose_buy a car                                                     0.113296
# Purpose_buy house                                                     0.072622
# Purpose_debt consolidation                                            0.405870
# Purpose_educational expenses                                          0.036039
# Purpose_home improvements                                             0.228414
# Purpose_major purchase                                                0.069842
# Purpose_medical bills                                                 0.098528
# Purpose_moving                                                        0.034627
# Purpose_other                                                         0.286807
# Purpose_small business                                                0.055602
# Purpose_take a trip                                                   0.070548
# Purpose_vacation                                                      0.033155
# Purpose_wedding                                                       0.041204
# Term_Long Term                                                        0.437764
# Term_Short Term                                                       0.437764
# annual_income_bigger_than_mean                                        0.488247
# ratio_ann_income/monthlydebt_                                         1.000050
# Mean_income_by_Years in current job                                   1.000050
# diff_Annual Income_and_mean_Annual Income_by_Years in current job     1.000050
# ratio_Annual Income_and_mean_Annual Income_by_Years in current job    1.000050
# Credit Score_changed                                                  0.421602
# dtype: float64

# %% [markdown]
# ## Разбиение на train и test

# %%
len(data) - data.count()
# Out:
# Home Ownership                                                           0
# Annual Income                                                            0
# Years in current job                                                     0
# Tax Liens                                                                0
# Number of Open Accounts                                                  0
# Years of Credit History                                                  0
# Maximum Open Credit                                                      0
# Number of Credit Problems                                                0
# Months since last delinquent                                             0
# Bankruptcies                                                             0
# Purpose                                                                  0
# Term                                                                     0
# Current Loan Amount                                                      0
# Current Credit Balance                                                   0
# Monthly Debt                                                             0
# Credit Score                                                             0
# Credit Default                                                        2500
# Home Ownership_Have Mortgage                                             0
# Home Ownership_Home Mortgage                                             0
# Home Ownership_Own Home                                                  0
# Home Ownership_Rent                                                      0
# Years in current job_1 year                                              0
# Years in current job_10+ years                                           0
# Years in current job_2 years                                             0
# Years in current job_3 years                                             0
# Years in current job_4 years                                             0
# Years in current job_5 years                                             0
# Years in current job_6 years                                             0
# Years in current job_7 years                                             0
# Years in current job_8 years                                             0
# Years in current job_9 years                                             0
# Years in current job_< 1 year                                            0
# Purpose_business loan                                                    0
# Purpose_buy a car                                                        0
# Purpose_buy house                                                        0
# Purpose_debt consolidation                                               0
# Purpose_educational expenses                                             0
# Purpose_home improvements                                                0
# Purpose_major purchase                                                   0
# Purpose_medical bills                                                    0
# Purpose_moving                                                           0
# Purpose_other                                                            0
# Purpose_small business                                                   0
# Purpose_take a trip                                                      0
# Purpose_vacation                                                         0
# Purpose_wedding                                                          0
# Term_Long Term                                                           0
# Term_Short Term                                                          0
# annual_income_bigger_than_mean                                           0
# ratio_ann_income/monthlydebt_                                            0
# Mean_income_by_Years in current job                                      0
# diff_Annual Income_and_mean_Annual Income_by_Years in current job        0
# ratio_Annual Income_and_mean_Annual Income_by_Years in current job       0
# Credit Score_changed                                                     0
# dtype: int64

# %%
# catboost выдает ошибку на знак < в названии признака, поэтому меняю название
data.rename(columns={'Years in current job_< 1 year': 'Years in current job_less 1 year'}, inplace=True)

# %%
data.columns.tolist()
# Out:
# ['Home Ownership',
#  'Annual Income',
#  'Years in current job',
#  'Tax Liens',
#  'Number of Open Accounts',
#  'Years of Credit History',
#  'Maximum Open Credit',
#  'Number of Credit Problems',
#  'Months since last delinquent',
#  'Bankruptcies',
#  'Purpose',
#  'Term',
#  'Current Loan Amount',
#  'Current Credit Balance',
#  'Monthly Debt',
#  'Credit Score',
#  'Credit Default',
#  'Home Ownership_Have Mortgage',
#  'Home Ownership_Home Mortgage',
#  'Home Ownership_Own Home',
#  'Home Ownership_Rent',
#  'Years in current job_1 year',
#  'Years in current job_10+ years',
#  'Years in current job_2 years',
#  'Years in current job_3 years',
#  'Years in current job_4 years',
#  'Years in current job_5 years',
#  'Years in current job_6 years',
#  'Years in current job_7 years',
#  'Years in current job_8 years',
#  'Years in current job_9 years',
#  'Years in current job_less 1 year',
#  'Purpose_business loan',
#  'Purpose_buy a car',
#  'Purpose_buy house',
#  'Purpose_debt consolidation',
#  'Purpose_educational expenses',
#  'Purpose_home improvements',
#  'Purpose_major purchase',
#  'Purpose_medical bills',
#  'Purpose_moving',
#  'Purpose_other',
#  'Purpose_small business',
#  'Purpose_take a trip',
#  'Purpose_vacation',
#  'Purpose_wedding',
#  'Term_Long Term',
#  'Term_Short Term',
#  'annual_income_bigger_than_mean',
#  'ratio_ann_income/monthlydebt_',
#  'Mean_income_by_Years in current job',
#  'diff_Annual Income_and_mean_Annual Income_by_Years in current job',
#  'ratio_Annual Income_and_mean_Annual Income_by_Years in current job',
#  'Credit Score_changed']

# %%
x_train = data[data["Credit Default"].notnull()]
x_test = data[data["Credit Default"].isnull()]

# %%
new_feature_names = ['annual_income_bigger_than_mean', 'Mean_income_by_Years in current job',
 'diff_Annual Income_and_mean_Annual Income_by_Years in current job',
 'ratio_Annual Income_and_mean_Annual Income_by_Years in current job', 'ratio_ann_income/monthlydebt_', 'Credit Score_changed']

# %%
feature_names = ['Annual Income',
 'Tax Liens',
 'Number of Open Accounts',
 'Years of Credit History',
 'Maximum Open Credit',
 'Number of Credit Problems',
 'Months since last delinquent',
 'Bankruptcies',
 'Current Loan Amount',
 'Current Credit Balance',
 'Monthly Debt',
 'Credit Score',
 'Home Ownership_Home Mortgage',
 'Home Ownership_Own Home',
 'Home Ownership_Rent',
'Home Ownership_Have Mortgage',
 'Years in current job_1 year',
 'Years in current job_10+ years',
 'Years in current job_2 years',
 'Years in current job_3 years',
 'Years in current job_4 years',
 'Years in current job_5 years',
 'Years in current job_6 years',
 'Years in current job_7 years',
 'Years in current job_8 years',
 'Years in current job_9 years',
 'Years in current job_less 1 year',
 'Purpose_business loan',
 'Purpose_buy a car',
 'Purpose_buy house',
 'Purpose_debt consolidation',
 'Purpose_educational expenses',
 'Purpose_home improvements',
 'Purpose_major purchase',
 'Purpose_medical bills',
 'Purpose_moving',
 'Purpose_other',
 'Purpose_small business',
 'Purpose_take a trip',
 'Purpose_vacation',
 'Purpose_wedding',
 'Term_Long Term',
 'Term_Short Term',]

target_name = 'Credit Default'

# %%
X = x_train[feature_names + new_feature_names]
y = x_train[target_name]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=21)

# %% [markdown]
# ### Балансировка целевой переменной

# %%
def balance_df_by_target(df, target_name):

    target_counts = df[target_name].value_counts()

    major_class_name = target_counts.argmax()
    minor_class_name = target_counts.argmin()

    disbalance_coeff = int(target_counts[major_class_name] / target_counts[minor_class_name]) - 1

    for i in range(disbalance_coeff):
        sample = df[df[target_name] == minor_class_name].sample(target_counts[minor_class_name])
        df = df.append(sample, ignore_index=True)

    return df.sample(frac=1)

# %%
data_for_balancing = pd.concat([X_train, y_train], axis=1)
data_balanced = balance_df_by_target(data_for_balancing, target_name)
    
data_balanced[target_name].value_counts()
# Out:
# 0.0    3622
# 1.0    2800
# Name: Credit Default, dtype: int64

# %%
X_train = data_balanced.drop(columns=target_name)
y_train = data_balanced[target_name]

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
model_catb = catb.CatBoostClassifier(class_weights=[1, 3.5], silent=True, random_state=21)
model_catb.fit(X_train, y_train)

y_train_pred = model_catb.predict(X_train)
y_test_pred = model_catb.predict(X_test)

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67      3622
#          1.0       0.61      1.00      0.76      2800
#
#     accuracy                           0.72      6422
#    macro avg       0.80      0.75      0.71      6422
# weighted avg       0.83      0.72      0.71      6422
#
# TEST
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.40      0.54      1762
#          1.0       0.37      0.86      0.51       713
#
#     accuracy                           0.53      2475
#    macro avg       0.62      0.63      0.53      2475
# weighted avg       0.73      0.53      0.54      2475
#
# CONFUSION MATRIX
#
# col_0           0.0   1.0
# Credit Default
# 0.0             696  1066
# 1.0             100   613

# %% [markdown]
# **Обучение и оценка финальной модели**

# %%
#%%time

final_model = catb.CatBoostClassifier(class_weights=[1, 1.3], max_depth=3, l2_leaf_reg=15,
                                      random_state=21, n_estimators=100, silent=True)
final_model.fit(X_train, y_train)

y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.59      0.65      3622
#          1.0       0.57      0.71      0.63      2800
#
#     accuracy                           0.64      6422
#    macro avg       0.65      0.65      0.64      6422
# weighted avg       0.66      0.64      0.64      6422
#
# TEST
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.59      0.70      1762
#          1.0       0.42      0.71      0.53       713
#
#     accuracy                           0.63      2475
#    macro avg       0.63      0.65      0.61      2475
# weighted avg       0.72      0.63      0.65      2475
#
# CONFUSION MATRIX
#
# col_0            0.0  1.0
# Credit Default
# 0.0             1048  714
# 1.0              204  509

# %%
x_test.shape
# Out:
# (2500, 54)

# %%
x_test.head()
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 7500           Rent      -0.955898              4 years  -0.103195
# 7501           Rent      -1.310678               1 year  -0.103195
# 7502  Home Mortgage      -0.267752              3 years  -0.103195
# 7503  Home Mortgage      -0.190982            10+ years  -0.103195
# 7504  Home Mortgage       1.078423              6 years  -0.103195
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 7500                -0.437897                -0.820099            -0.353907
# 7501                -1.050785                 2.027646            -0.477978
# 7502                -0.233601                -0.650926            -0.366213
# 7503                 0.992176                -0.185700            -0.176972
# 7504                -0.029305                 0.744751             0.387640
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 7500                  -0.326391                     -1.091936      -0.33411
# 7501                  -0.326391                     -1.091936      -0.33411
# 7502                  -0.326391                      0.915804      -0.33411
# 7503                  -0.326391                     -1.091936      -0.33411
# 7504                  -0.326391                      0.915804      -0.33411
#
#       ... Purpose_vacation Purpose_wedding  Term_Long Term  Term_Short Term  \
# 7500  ...                0               0               0                1
# 7501  ...                0               0               0                1
# 7502  ...                0               0               0                1
# 7503  ...                0               0               0                1
# 7504  ...                0               0               1                0
#
#       annual_income_bigger_than_mean  ratio_ann_income/monthlydebt_  \
# 7500                               0                      -0.017197
# 7501                               0                      -0.015900
# 7502                               0                      -0.018393
# 7503                               0                      -0.019512
# 7504                               1                      -0.018820
#
#       Mean_income_by_Years in current job  \
# 7500                            -0.472328
# 7501                            -1.482705
# 7502                            -0.077690
# 7503                             0.945600
# 7504                            -0.248054
#
#       diff_Annual Income_and_mean_Annual Income_by_Years in current job  \
# 7500                                          -0.915503
# 7501                                          -1.176334
# 7502                                          -0.261600
# 7503                                          -0.281239
# 7504                                           1.106686
#
#       ratio_Annual Income_and_mean_Annual Income_by_Years in current job  \
# 7500                                          -0.939809
# 7501                                          -1.287670
# 7502                                          -0.262176
# 7503                                          -0.265526
# 7504                                           1.120594
#
#       Credit Score_changed
# 7500                     1
# 7501                     0
# 7502                     0
# 7503                     0
# 7504                     0
#
# [5 rows x 54 columns]

# %%
x_valid = x_test[feature_names + new_feature_names]

# %%
x_valid
# Out:
#       Annual Income  Tax Liens  Number of Open Accounts  \
# 7500      -0.955898  -0.103195                -0.437897
# 7501      -1.310678  -0.103195                -1.050785
# 7502      -0.267752  -0.103195                -0.233601
# 7503      -0.190982  -0.103195                 0.992176
# 7504       1.078423  -0.103195                -0.029305
# ...             ...        ...                      ...
# 9995      -0.417827  -0.103195                 0.583583
# 9996       1.416807  -0.103195                 0.787880
# 9997      -0.245928  -0.103195                 7.529650
# 9998      -0.753725  -0.103195                 0.583583
# 9999       0.346085  -0.103195                 0.174991
#
#       Years of Credit History  Maximum Open Credit  Number of Credit Problems  \
# 7500                -0.820099            -0.353907                  -0.326391
# 7501                 2.027646            -0.477978                  -0.326391
# 7502                -0.650926            -0.366213                  -0.326391
# 7503                -0.185700            -0.176972                  -0.326391
# 7504                 0.744751             0.387640                  -0.326391
# ...                       ...                  ...                        ...
# 9995                 1.520127            -0.099645                   1.616986
# 9996                -0.185700             0.786500                  -0.326391
# 9997                -0.777806             0.762930                  -0.326391
# 9998                 1.477834             0.191039                  -0.326391
# 9999                 0.011668             0.381984                   1.616986
#
#       Months since last delinquent  Bankruptcies  Current Loan Amount  \
# 7500                     -1.091936     -0.334110            -0.862181
# 7501                     -1.091936     -0.334110            -1.353343
# 7502                      0.915804     -0.334110            -0.642147
# 7503                     -1.091936     -0.334110            -0.541758
# 7504                      0.915804     -0.334110             2.727431
# ...                            ...           ...                  ...
# 9995                     -1.091936      2.642803             0.008841
# 9996                     -1.091936     -0.334110             0.923638
# 9997                      0.915804     -0.334110             0.701807
# 9998                      0.915804     -0.334110            -0.306062
# 9999                     -1.091936     -0.334110             2.642061
#
#       Current Credit Balance  ...  Purpose_vacation  Purpose_wedding  \
# 7500               -0.555520  ...                 0                0
# 7501               -0.735010  ...                 0                0
# 7502               -0.433847  ...                 0                0
# 7503               -0.233850  ...                 0                0
# 7504                0.402313  ...                 0                0
# ...                      ...  ...               ...              ...
# 9995               -0.385144  ...                 0                0
# 9996                3.441972  ...                 0                0
# 9997                1.154965  ...                 0                0
# 9998                0.299950  ...                 0                0
# 9999                0.804471  ...                 0                0
#
#       Term_Long Term  Term_Short Term  annual_income_bigger_than_mean  \
# 7500               0                1                               0
# 7501               0                1                               0
# 7502               0                1                               0
# 7503               0                1                               0
# 7504               1                0                               1
# ...              ...              ...                             ...
# 9995               0                1                               0
# 9996               0                1                               1
# 9997               0                1                               0
# 9998               0                1                               0
# 9999               1                0                               1
#
#       Mean_income_by_Years in current job  \
# 7500                            -0.472328
# 7501                            -1.482705
# 7502                            -0.077690
# 7503                             0.945600
# 7504                            -0.248054
# ...                                   ...
# 9995                             0.945600
# 9996                            -0.725185
# 9997                            -0.725185
# 9998                             0.945600
# 9999                             0.945600
#
#       diff_Annual Income_and_mean_Annual Income_by_Years in current job  \
# 7500                                          -0.915503
# 7501                                          -1.176334
# 7502                                          -0.261600
# 7503                                          -0.281239
# 7504                                           1.106686
# ...                                                 ...
# 9995                                          -0.509096
# 9996                                           1.491692
# 9997                                          -0.178459
# 9998                                          -0.846492
# 9999                                           0.258222
#
#       ratio_Annual Income_and_mean_Annual Income_by_Years in current job  \
# 7500                                          -0.939809
# 7501                                          -1.287670
# 7502                                          -0.262176
# 7503                                          -0.265526
# 7504                                           1.120594
# ...                                                 ...
# 9995                                          -0.480651
# 9996                                           1.555513
# 9997                                          -0.186095
# 9998                                          -0.799195
# 9999                                           0.243795
#
#       ratio_ann_income/monthlydebt_  Credit Score_changed
# 7500                      -0.017197                     1
# 7501                      -0.015900                     0
# 7502                      -0.018393                     0
# 7503                      -0.019512                     0
# 7504                      -0.018820                     0
# ...                             ...                   ...
# 9995                      -0.017988                     0
# 9996                      -0.017197                     1
# 9997                      -0.020324                     0
# 9998                      -0.018910                     0
# 9999                      -0.017697                     0
#
# [2500 rows x 49 columns]

# %%
Credit_Default_predicted = final_model.predict(x_valid)
Credit_Default_predicted
# Out:
# array([1., 1., 1., ..., 1., 0., 1.])

# %%
len(Credit_Default_predicted)
# Out:
# 2500

# %%
results = pd.DataFrame({'Credit_Default_predicted': Credit_Default_predicted}, columns=['Credit_Default_predicted'])
results
# Out:
#       Credit_Default_predicted
# 0                          1.0
# 1                          1.0
# 2                          1.0
# 3                          0.0
# 4                          1.0
# ...                        ...
# 2495                       0.0
# 2496                       0.0
# 2497                       1.0
# 2498                       0.0
# 2499                       1.0
#
# [2500 rows x 1 columns]

# %% [markdown]
# ### Сохранение предсказания

# %%
RESULTS_FILE_PATH = 'LSbitneva_predictions.csv'
results.to_csv(RESULTS_FILE_PATH, index=False)
